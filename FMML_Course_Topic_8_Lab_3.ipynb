# %% [markdown]
# <a href="https://colab.research.google.com/github/Toletisuresh/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-30 11:02:46--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   127MB/s    in 0.5s
#
# 2023-05-30 11:02:49 (127 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 37361  1704.08716v1  Artificial intelligence methods have often bee...    cs
# 22975  1712.00520v1  Identifying altered pathways that are associat...  stat
# 6055   1606.05896v1  A good clustering can help a data analyst to e...  stat
# 22584  1701.08916v2  Prototypal analysis is introduced to overcome ...  stat
# 15197  1612.02706v2  Standard approaches in entity identification h...    cs
# ...             ...                                                ...   ...
# 36173   1207.6199v1  In recent years, data streaming has gained pro...    cs
# 27129  1702.04593v3  This paper addresses the problem of multi-view...    cs
# 19702   1109.5711v1  We present a partial-order, conformant, probab...    cs
# 34580  1704.03940v3  In order to adopt deep learning for informatio...    cs
# 22303  1512.05610v2  We propose a novel classification model for we...  stat
#
#                                                    title  year  \
# 37361     Artificial Intelligence Based Malware Analysis  2017
# 22975  Bayesian Semi-nonnegative Tri-matrix Factoriza...  2017
# 6055   Clustering with a Reject Option: Interactive C...  2016
# 22584      Prototypal Analysis and Prototypal Regression  2017
# 15197              Entity Identification as Multitasking  2016
# ...                                                  ...   ...
# 36173  Achieving Approximate Soft Clustering in Data ...  2012
# 27129                 Deep Multi-camera People Detection  2017
# 19702     Engineering a Conformant Probabilistic Planner  2011
# 34580  PACRR: A Position-Aware Neural IR Model for Re...  2017
# 22303  Classification of weak multi-view signals by s...  2015
#
#                                                 keywords
# 37361  [artificial, intelligence, functions, adversar...
# 22975  [identifying, associated, potentially, signifi...
# 6055   [clustering, understand, constitutes, clusteri...
# 22584  [prototypal, introduced, shortcomings, archety...
# 15197  [approaches, identification, detection, predic...
# ...                                                  ...
# 36173  [streaming, prominence, technologies, applicat...
# 27129  [addresses, occupancy, estimation, solutions, ...
# 19702  [conformant, probabilistic, probabilistic, com...
# 34580  [information, retrieval, information, relevanc...
# 22303  [classification, different, producing, differe...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 37361    [artificial, intelligence, functions, adversar...
# 22975    [identifying, associated, potentially, signifi...
# 6055     [clustering, understand, constitutes, clusteri...
# 22584    [prototypal, introduced, shortcomings, archety...
# 15197    [approaches, identification, detection, predic...
#                                ...
# 19146    [systematically, consistency, constraints, nor...
# 23929    [uncertainty, maximisation, information, opera...
# 11940    [completion, formulations, recommender, perfor...
# 21756    [probabilistic, multiscale, representation, fo...
# 2694     [introduce, formulation, parameter, framework,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8739 words.
# Out of those 4584 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="cb555eb4-2b57-4a3d-809a-751a0c3c75ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb555eb4-2b57-4a3d-809a-751a0c3c75ac")) {                    Plotly.newPlot(                        "cb555eb4-2b57-4a3d-809a-751a0c3c75ac",                        [{"x":["particular","attributed","biologically","hopefully","sufficient","similarities","development","information","promising","sophistication","biological","integration","artificial","adversary","piecemeal","functions","understand","intelligence","capability","providing","techniques","ecosystem","difficult","characteristics","communities","underlying","significant","databases","identification","successfully","posterior","prognostic","biomarkers","identified","therapeutic","associated","appealing","knowledge","factorization","molecular","distributions","different","associations","nonnegative","treatment","dependent","identifying","represented","biomedical","bernoulli","interaction","mechanisms","likelihood","variables","efficient","straightforward","overfitting","calculate","potentially","distribution","clustering","randomized","application","clusterings","interactive","constitutes","formalize","equivalent","exploration","mechanism","particularly","previously","elicitation","framework","discourage","embedding","probability","archetypes","regression","combination","applicability","procedure","interpretable","convexity","archetypal","prototypes","reconstruction","sensitivity","developed","shortcomings","approximates","supervised","introduced","detection","simplicity","complexity","separating","disadvantages","representation","embeddings","addresses","architecture","structured","furthermore","construction","predicted","approaches","optimizing","quadratically","prediction","competitively","disambiguating","excellent","algorithms","introduce","parameter","plentiful","objective","unlabeled","empirical","theoretical","learnability","parametric","performance","stability","uninformative","predictive","principle","applicable","suppressing","asymptotic","analogous","uniformly","inference","including","perspective","weighting","interpretations","generically","maximally","estimator","demonstrate","regularization","paradigms","understood","criterion","statistical","definition","frequentist","distinguishable","registers","highlighting","computation","introduction","computers","available","guidelines","principles","overviews","references","potential","computationally","extracted","presented","technique","experiments","constraints","horizontal","histogram","preprocessing","challenging","challenges","correction","segmentation","characters","researchers","developing","extraction","deformation","segmented","moderately","segmenting","corrected","computational","character","naturally","implicitly","filtering","universality","comparative","assessing","literature","advantages","independent","kronecker","limitations","instantiations","formulated","consistency","predicting"],"y":[273,14,10,4,50,29,125,698,113,4,40,51,121,11,2,214,68,94,48,92,376,4,151,90,15,101,224,53,104,95,39,4,3,42,0,105,20,366,39,7,133,750,10,7,30,75,71,82,18,5,83,54,60,130,403,21,22,14,47,204,141,23,242,5,41,11,10,57,64,95,90,113,8,541,1,116,169,0,121,148,28,115,26,7,0,7,83,25,193,15,12,199,108,334,22,241,5,9,388,82,53,233,105,167,74,44,449,52,3,259,5,2,28,606,321,116,2,167,43,159,146,5,42,887,30,0,60,51,60,6,15,14,15,218,268,64,30,13,2,6,25,551,73,10,21,48,168,46,1,4,2,13,133,35,16,295,10,45,1,7,170,98,116,168,248,595,138,9,20,28,290,139,21,220,24,74,65,128,13,18,2,27,13,273,48,57,20,54,2,34,18,135,95,162,3,61,4,43,61,93],"type":"bar"},{"x":["particular","attributed","biologically","hopefully","sufficient","similarities","development","inform ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4584,), (4584, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7883333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>CAPIO</span> <span style=''>2017</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Conversational</span> <span style=''>Speech</span> <span style='background-color:rgba(0, 255, 0, 0.603448275862069);'>Recognition</span> <span style=''>System</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>we</span> <span style=''>have</span> <span style=''>achieved</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>the</span> <span style=''>industry</span> <span style=''>standard</span> <span style=''>NIST</span> <span style=''>2000</span> <span style=''>Hub5</span> <span style=''>English</span> <span style='background-color:rgba(0, 255, 0, 0.40482573726541554);'>evaluation</span> <span style=''>set</span> <span style=''>We</span> <span style=''>explore</span> <span style=''>densely</span> <span style='background-color:rgba(0, 255, 0, 0.40740740740740733);'>connected</span> <span style=''>LSTMs</span> <span style=''>inspired</span> <span style=''>by</span> <span style=''>the</span> <span style=''>densely</span> <span style='background-color:rgba(0, 255, 0, 0.40740740740740733);'>connected</span> <span style='background-color:rgba(0, 255, 0, 0.5689655172413794);'>convolutional</span> <span style=''>networks</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>for</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>tasks</span> <span style=''>We</span> <span style=''>also</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>acoustic</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.31372549019607837);'>adaptation</span> <span style=''>scheme</span> <span style=''>that</span> <span style=''>simply</span> <span style=''>averages</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>a</span> <span style=''>seed</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>acoustic</span> <span style=''>model</span> <span style=''>and</span> <span style=''>its</span> <span style=''>adapted</span> <span style=''>version</span> <span style=''>This</span> <span style=''>method</span> <span style=''>was</span> <span style=''>applied</span> <span style=''>with</span> <span style=''>the</span> <span style=''>CallHome</span> <span style=''>training</span> <span style=''>corpus</span> <span style=''>and</span> <span style=''>improved</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individual</span> <span style=''>system</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performances</span> <span style=''>by</span> <span style=''>on</span> <span style=''>average</span> <span style=''>61</span> <span style=''>(relative)</span> <span style=''>against</span> <span style=''>the</span> <span style=''>CallHome</span> <span style=''>portion</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.40482573726541554);'>evaluation</span> <span style=''>set</span> <span style=''>with</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>loss</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Switchboard</span> <span style=''>portion</span> <span style=''>With</span> <span style=''>RNN</span> <span style=''>LM</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>rescoring</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Spontaneous</span> <span style=''>Symmetry</span> <span style=''>Breaking</span> <span style=''>in</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understand</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unprecedented</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>robustness</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>using</span> <span style=''>field</span> <span style=''>theory</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Correlations</span> <span style=''>between</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>within</span> <span style=''>the</span> <span style=''>same</span> <span style=''>layer</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>described</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetries</span> <span style=''>in</span> <span style=''>that</span> <span style=''>layer</span> <span style=''>and</span> <span style=''>networks</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>better</span> <span style=''>if</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetries</span> <span style=''>are</span> <span style=''>broken</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>redundancies</span> <span style=''>of</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>Using</span> <span style=''>a</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>field</span> <span style=''>theory</span> <span style=''>we</span> <span style=''>find</span> <span style=''>that</span> <span style=''>the</span> <span style=''>network</span> <span style=''>can</span> <span style=''>break</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetries</span> <span style=''>itself</span> <span style=''>towards</span> <span style=''>the</span> <span style=''>end</span> <span style=''>of</span> <span style=''>training</span> <span style=''>in</span> <span style=''>a</span> <span style=''>process</span> <span style=''>commonly</span> <span style=''>known</span> <span style=''>in</span> <span style=''>physics</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>spontaneous</span> <span style=''>symmetry</span> <span style=''>breaking</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponds</span> <span style=''>to</span> <span style=''>a</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizing</span> <span style=''>itself</span> <span style=''>without</span> <span style=''>any</span> <span style=''>user</span> <span style=''>input</span> <span style=''>layers</span> <span style=''>to</span> <span style=''>break</span> <span style=''>the</span> <span style=''>symmetry</span> <span style=''>but</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>communication</span> <span style=''>with</span> <span style=''>adjacent</span> <span style=''>layers</span> <span style=''>In</span> <span style=''>the</span> <span style=''>layer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decoupling</span> <span style=''>limit</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Note</span> <span style=''>on</span> <span style=''>Improved</span> <span style=''>Loss</span> <span style=''>Bounds</span> <span style=''>for</span> <span style=''>Multiple</span> <span style=''>Kernel</span> <span style=''>Learning</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>correct</span> <span style=''>an</span> <span style=''>upper</span> <span style=''>bound</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>presented</span> <span style=''>incitehs</span> <span style=''>11</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalisation</span> <span style=''>error</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>learned</span> <span style=''>through</span> <span style=''>multiple</span> <span style=''>kernel</span> <span style=''>learning</span> <span style=''>The</span> <span style=''>bound</span> <span style=''>incitehs</span> <span style=''>11</span> <span style=''>uses</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Rademacher</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>and</span> <span style=''>has</span> <span style=''>anemphadditive</span> <span style='background-color:rgba(255, 0, 0, 0.42105263157894746);'>dependence</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>logarithm</span> <span style=''>of</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>kernels</span> <span style=''>and</span> <span style=''>the</span> <span style=''>margin</span> <span style=''>achieved</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>However</span> <span style=''>there</span> <span style=''>are</span> <span style=''>some</span> <span style=''>errors</span> <span style=''>in</span> <span style=''>parts</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proof</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrected</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unfortunately</span> <span style=''>the</span> <span style=''>final</span> <span style=''>result</span> <span style=''>turns</span> <span style=''>out</span> <span style=''>to</span> <span style=''>be</span> <span style=''>a</span> <span style=''>risk</span> <span style=''>bound</span> <span style=''>which</span> <span style=''>has</span> <span style=''>a</span> <span style=''>emphmultiplicative</span> <span style='background-color:rgba(255, 0, 0, 0.42105263157894746);'>dependence</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>logarithm</span> <span style=''>of</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>kernels</span> <span style=''>and</span> <span style=''>the</span> <span style=''>margin</span> <span style=''>achieved</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Orthogonal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>with</span> <span style=''>Scaled</span> <span style=''>Cayley</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Transform</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(RNNs)</span> <span style=''>are</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>handle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>data</span> <span style=''>but</span> <span style=''>suffer</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>vanishing</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>gradients</span> <span style=''>Recent</span> <span style=''>work</span> <span style=''>on</span> <span style=''>Unitary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(uRNNs)</span> <span style=''>have</span> <span style=''>been</span> <span style=''>used</span> <span style=''>to</span> <span style=''>address</span> <span style=''>this</span> <span style=''>issue</span> <span style=''>and</span> <span style=''>in</span> <span style=''>some</span> <span style=''>cases</span> <span style=''>exceed</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>capabilities</span> <span style=''>of</span> <span style=''>Long</span> <span style=''>Short</span> <span style=''>Term</span> <span style=''>Memory</span> <span style=''>networks</span> <span style=''>(LSTMs)</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>simpler</span> <span style=''>and</span> <span style=''>novel</span> <span style=''>update</span> <span style=''>scheme</span> <span style=''>to</span> <span style=''>maintain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>weight</span> <span style=''>matrices</span> <span style=''>without</span> <span style=''>using</span> <span style=''>complex</span> <span style=''>valued</span> <span style=''>matrices</span> <span style=''>This</span> <span style=''>is</span> <span style=''>done</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrizing</span> <span style=''>with</span> <span style=''>a</span> <span style=''>skew</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetric</span> <span style=''>matrix</span> <span style=''>using</span> <span style=''>the</span> <span style=''>Cayley</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>Such</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrization</span> <span style=''>is</span> <span style=''>unable</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>matrices</span> <span style=''>with</span> <span style=''>negative</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvalues</span> <span style=''>but</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>limitation</span> <span style=''>is</span> <span style=''>overcome</span> <span style=''>by</span> <span style=''>scaling</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>weight</span> <span style=''>matrix</span> <span style=''>by</span> <span style=''>a</span> <span style=''>diagon ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.05115452930728242)
# 	challenging (0.10301953818827708)
# 	information (0.24795737122557726)
# 	knowledge (0.1300177619893428)
# 	segmentation (0.07815275310834814)
# 	detection (0.11865008880994671)
# 	representation (0.13783303730017762)
# 	different (0.2664298401420959)
# 	convolutional (0.12930728241563055)
# 	recognition (0.1321492007104796)
#
# Some Statistics words are:
# 	stochastic (0.12795969773299748)
# 	statistical (0.1526448362720403)
# 	algorithm (0.382367758186398)
# 	variables (0.14458438287153652)
# 	theoretical (0.1526448362720403)
# 	distribution (0.17581863979848866)
# 	estimation (0.17279596977329975)
# 	inference (0.1858942065491184)
# 	dimensional (0.17934508816120906)
# 	regression (0.17984886649874054)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="719d0b88-9d05-41c3-9479-ea4f1e566b57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("719d0b88-9d05-41c3-9479-ea4f1e566b57")) {                    Plotly.newPlot(                        "719d0b88-9d05-41c3-9479-ea4f1e566b57",                        [{"x":["particular","attributed","biologically","hopefully","sufficient","similarities","development","information","promising","sophistication","biological","integration","artificial","adversary","piecemeal","functions","understand","intelligence","capability","providing","techniques","ecosystem","difficult","characteristics","communities","underlying","significant","databases","identification","successfully","posterior","prognostic","biomarkers","identified","therapeutic","associated","appealing","knowledge","factorization","molecular","distributions","different","associations","nonnegative","treatment","dependent","identifying","represented","biomedical","bernoulli","interaction","mechanisms","likelihood","variables","efficient","straightforward","overfitting","calculate","potentially","distribution","clustering","randomized","application","clusterings","interactive","constitutes","formalize","equivalent","exploration","mechanism","particularly","previously","elicitation","framework","discourage","embedding","probability","archetypes","regression","combination","applicability","procedure","interpretable","convexity","archetypal","prototypes","reconstruction","sensitivity","developed","shortcomings","approximates","supervised","introduced","detection","simplicity","complexity","separating","disadvantages","representation","embeddings","addresses","architecture","structured","furthermore","construction","predicted","approaches","optimizing","quadratically","prediction","competitively","disambiguating","excellent","algorithms","introduce","parameter","plentiful","objective","unlabeled","empirical","theoretical","learnability","parametric","performance","stability","uninformative","predictive","principle","applicable","suppressing","asymptotic","analogous","uniformly","inference","including","perspective","weighting","interpretations","generically","maximally","estimator","demonstrate","regularization","paradigms","understood","criterion","statistical","definition","frequentist","distinguishable","registers","highlighting","computation","introduction","computers","available","guidelines","principles","overviews","references","potential","computationally","extracted","presented","technique","experiments","constraints","horizontal","histogram","preprocessing","challenging","challenges","correction","segmentation","characters","researchers","developing","extraction","deformation","segmented","moderately","segmenting","corrected","computational","character","naturally","implicitly","filtering","universality","comparative","assessing","literature","advantages","independent","kronecker","limitations","instantiations","formulated","consistency","predicting","properties","accompanied","highlights","simulations","guarantees","cumulative","advertising","assumption","acquiring","stationary","scenarios","specifically","classical","motivated","extensively","leveraging","crowdsourcing","recommendation","architectures","representations","simulation","connection","environment","reinforcement","increasingly","actuation","unstructured","unreliable","structures","forecasting","simulated","drawbacks","approximation","evaluated","initialization","applications","minimization","established","robustness","manifolds","processing","extremely","interactions","structure","exploited","semantics","similarity","theoretic","analyzing","entailment","intuitively","generalizations","commonalities","generalization","operators" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	therapeutic
# 	archetypes
# 	archetypal
# 	uninformative
# 	traintest
# 	telescope
# 	marginalize
# 	heteroscedasticity
# 	discriminable
# 	methodologically
# 	individualized
# 	dependences
# 	strikingly
# 	hermitian
# 	regularizations
# 	composers
# 	jackknife
# 	quantiles
# 	incidentally
# 	stochasticity
# Some words which never appear in Statistics papers:
# 	piecemeal
# 	disambiguating
# 	characters
# 	actuation
# 	metaheuristic
# 	campaigns
# 	telecommunication
# 	investment
# 	managerial
# 	marquardt
# 	underline
# 	cooperate
# 	passwords
# 	endmembers
# 	correspondences
# 	purchased
# 	justifications
# 	articulated
# 	nonmonotonic
# 	displacements

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0549275982159226e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.755
